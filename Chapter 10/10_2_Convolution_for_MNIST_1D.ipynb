# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\risha\appdata\local\temp\pip-req-build-d9z8ghfk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\risha\appdata\roaming\python\python314\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in c:\users\risha\appdata\roaming\python\python314\site-packages (from mnist1d==0.0.2.post16) (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\risha\appdata\roaming\python\python314\site-packages (from mnist1d==0.0.2.post16) (3.10.7)
# Requirement already satisfied: scipy in c:\users\risha\appdata\roaming\python\python314\site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\risha\appdata\roaming\python\python314\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\risha\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\risha\appdata\roaming\python\python314\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\risha\appdata\roaming\python\python314\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\risha\appdata\roaming\python\python314\site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\risha\appdata\roaming\python\python314\site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\risha\AppData\Local\Temp\pip-req-build-d9z8ghfk'

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=True, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Downloading MNIST1D dataset from https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl
# Saving to ./mnist1d_data.pkl
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Conv1d(1,15,3,2,0),
nn.ReLU(),
nn.Conv1d(15,15,3,2,0),
nn.ReLU(),
nn.Conv1d(15,15,3,2,0),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.655012, train error 65.00,  val loss 1.682792, percent error 66.90
# Epoch     1, train loss 1.393549, train error 55.85,  val loss 1.407572, percent error 57.70
# Epoch     2, train loss 1.192581, train error 50.05,  val loss 1.228008, percent error 54.20
# Epoch     3, train loss 1.189543, train error 47.55,  val loss 1.257187, percent error 52.10
# Epoch     4, train loss 1.029809, train error 42.60,  val loss 1.114484, percent error 45.70
# Epoch     5, train loss 0.845107, train error 35.12,  val loss 0.936439, percent error 38.40
# Epoch     6, train loss 0.753662, train error 31.85,  val loss 0.855480, percent error 36.40
# Epoch     7, train loss 0.666623, train error 28.62,  val loss 0.766951, percent error 32.50
# Epoch     8, train loss 0.594033, train error 23.90,  val loss 0.722788, percent error 27.80
# Epoch     9, train loss 0.539448, train error 22.00,  val loss 0.656008, percent error 26.30
# Epoch    10, train loss 0.503335, train error 20.93,  val loss 0.614742, percent error 25.40
# Epoch    11, train loss 0.408206, train error 16.10,  val loss 0.526777, percent error 21.60
# Epoch    12, train loss 0.378939, train error 14.50,  val loss 0.511649, percent error 19.70
# Epoch    13, train loss 0.417312, train error 17.03,  val loss 0.588020, percent error 22.80
# Epoch    14, train loss 0.372013, train error 13.57,  val loss 0.569225, percent error 19.40
# Epoch    15, train loss 0.306857, train error 11.00,  val loss 0.462773, percent error 16.70
# Epoch    16, train loss 0.297771, train error 11.50,  val loss 0.471477, percent error 17.60
# Epoch    17, train loss 0.163900, train error 5.20,  val loss 0.363137, percent error 13.80
# Epoch    18, train loss 0.209107, train error 7.50,  val loss 0.415955, percent error 13.30
# Epoch    19, train loss 0.190208, train error 7.12,  val loss 0.449063, percent error 16.20
# Epoch    20, train loss 0.101414, train error 3.28,  val loss 0.351643, percent error 11.30
# Epoch    21, train loss 0.062848, train error 1.70,  val loss 0.359401, percent error 11.40
# Epoch    22, train loss 0.054199, train error 1.65,  val loss 0.356437, percent error 12.00
# Epoch    23, train loss 0.051274, train error 1.60,  val loss 0.373714, percent error 10.90
# Epoch    24, train loss 0.038924, train error 1.03,  val loss 0.364299, percent error 11.10
# Epoch    25, train loss 0.029236, train error 0.65,  val loss 0.383084, percent error 11.10
# Epoch    26, train loss 0.025957, train error 0.53,  val loss 0.404780, percent error 11.80
# Epoch    27, train loss 0.023466, train error 0.45,  val loss 0.402640, percent error 11.40
# Epoch    28, train loss 0.032406, train error 0.80,  val loss 0.423906, percent error 11.10
# Epoch    29, train loss 0.035374, train error 1.10,  val loss 0.459296, percent error 13.40
# Epoch    30, train loss 0.046638, train error 1.45,  val loss 0.485094, percent error 11.90
# Epoch    31, train loss 0.030808, train error 0.88,  val loss 0.419521, percent error 10.10
# Epoch    32, train loss 0.020051, train error 0.40,  val loss 0.482590, percent error 11.60
# Epoch    33, train loss 0.009471, train error 0.05,  val loss 0.448725, percent error 10.80
# Epoch    34, train loss 0.006678, train error 0.03,  val loss 0.445726, percent error 10.20
# Epoch    35, train loss 0.005466, train error 0.00,  val loss 0.454341, percent error 10.50
# Epoch    36, train loss 0.004746, train error 0.00,  val loss 0.478973, percent error 10.60
# Epoch    37, train loss 0.004008, train error 0.00,  val loss 0.475398, percent error 10.70
# Epoch    38, train loss 0.003768, train error 0.00,  val loss 0.481362, percent error 11.10
# Epoch    39, train loss 0.003324, train error 0.00,  val loss 0.503305, percent error 10.90
# Epoch    40, train loss 0.002740, train error 0.00,  val loss 0.495885, percent error 10.90
# Epoch    41, train loss 0.002612, train error 0.00,  val loss 0.502789, percent error 10.90
# Epoch    42, train loss 0.002509, train error 0.00,  val loss 0.505097, percent error 11.00
# Epoch    43, train loss 0.002436, train error 0.00,  val loss 0.513471, percent error 10.90
# Epoch    44, train loss 0.002327, train error 0.00,  val loss 0.514634, percent error 10.80
# Epoch    45, train loss 0.002260, train error 0.00,  val loss 0.520506, percent error 11.10
# Epoch    46, train loss 0.002163, train error 0.00,  val loss 0.515684, percent error 11.00
# Epoch    47, train loss 0.002069, train error 0.00,  val loss 0.523430, percent error 10.90
# Epoch    48, train loss 0.001995, train error 0.00,  val loss 0.524208, percent error 10.90
# Epoch    49, train loss 0.001946, train error 0.00,  val loss 0.525950, percent error 10.90
# Epoch    50, train loss 0.001886, train error 0.00,  val loss 0.528953, percent error 11.00
# Epoch    51, train loss 0.001817, train error 0.00,  val loss 0.531214, percent error 11.00
# Epoch    52, train loss 0.001771, train error 0.00,  val loss 0.532526, percent error 11.00
# Epoch    53, train loss 0.001720, train error 0.00,  val loss 0.538936, percent error 10.90
# Epoch    54, train loss 0.001664, train error 0.00,  val loss 0.542993, percent error 10.90
# Epoch    55, train loss 0.001628, train error 0.00,  val loss 0.539474, percent error 11.10
# Epoch    56, train loss 0.001571, train error 0.00,  val loss 0.542476, percent error 10.90
# Epoch    57, train loss 0.001534, train error 0.00,  val loss 0.546622, percent error 11.10
# Epoch    58, train loss 0.001495, train error 0.00,  val loss 0.549017, percent error 11.10
# Epoch    59, train loss 0.001462, train error 0.00,  val loss 0.548936, percent error 11.00
# Epoch    60, train loss 0.001442, train error 0.00,  val loss 0.552860, percent error 11.10
# Epoch    61, train loss 0.001417, train error 0.00,  val loss 0.551119, percent error 11.10
# Epoch    62, train loss 0.001399, train error 0.00,  val loss 0.553522, percent error 11.10
# Epoch    63, train loss 0.001384, train error 0.00,  val loss 0.553669, percent error 11.00
# Epoch    64, train loss 0.001367, train error 0.00,  val loss 0.554887, percent error 11.00
# Epoch    65, train loss 0.001350, train error 0.00,  val loss 0.555432, percent error 11.10
# Epoch    66, train loss 0.001335, train error 0.00,  val loss 0.556006, percent error 11.10
# Epoch    67, train loss 0.001319, train error 0.00,  val loss 0.557198, percent error 11.10
# Epoch    68, train loss 0.001307, train error 0.00,  val loss 0.558442, percent error 11.00
# Epoch    69, train loss 0.001291, train error 0.00,  val loss 0.559684, percent error 11.00
# Epoch    70, train loss 0.001279, train error 0.00,  val loss 0.559093, percent error 11.10
# Epoch    71, train loss 0.001264, train error 0.00,  val loss 0.561019, percent error 11.00
# Epoch    72, train loss 0.001248, train error 0.00,  val loss 0.561831, percent error 11.00
# Epoch    73, train loss 0.001234, train error 0.00,  val loss 0.562673, percent error 11.00
# Epoch    74, train loss 0.001221, train error 0.00,  val loss 0.563709, percent error 11.10
# Epoch    75, train loss 0.001209, train error 0.00,  val loss 0.564530, percent error 11.00
# Epoch    76, train loss 0.001195, train error 0.00,  val loss 0.565610, percent error 11.00
# Epoch    77, train loss 0.001184, train error 0.00,  val loss 0.567107, percent error 11.00
# Epoch    78, train loss 0.001171, train error 0.00,  val loss 0.566998, percent error 11.00
# Epoch    79, train loss 0.001161, train error 0.00,  val loss 0.566916, percent error 11.10
# Epoch    80, train loss 0.001152, train error 0.00,  val loss 0.568010, percent error 11.00
# Epoch    81, train loss 0.001146, train error 0.00,  val loss 0.568421, percent error 11.00
# Epoch    82, train loss 0.001141, train error 0.00,  val loss 0.568911, percent error 11.20
# Epoch    83, train loss 0.001135, train error 0.00,  val loss 0.569426, percent error 11.10
# Epoch    84, train loss 0.001129, train error 0.00,  val loss 0.569550, percent error 11.10
# Epoch    85, train loss 0.001124, train error 0.00,  val loss 0.570116, percent error 11.10
# Epoch    86, train loss 0.001118, train error 0.00,  val loss 0.570210, percent error 11.20
# Epoch    87, train loss 0.001113, train error 0.00,  val loss 0.570844, percent error 11.20
# Epoch    88, train loss 0.001107, train error 0.00,  val loss 0.571112, percent error 11.20
# Epoch    89, train loss 0.001102, train error 0.00,  val loss 0.571696, percent error 11.20
# Epoch    90, train loss 0.001097, train error 0.00,  val loss 0.572117, percent error 11.10
# Epoch    91, train loss 0.001091, train error 0.00,  val loss 0.572560, percent error 11.10
# Epoch    92, train loss 0.001086, train error 0.00,  val loss 0.572913, percent error 11.20
# Epoch    93, train loss 0.001081, train error 0.00,  val loss 0.573397, percent error 11.10
# Epoch    94, train loss 0.001076, train error 0.00,  val loss 0.574002, percent error 11.20
# Epoch    95, train loss 0.001071, train error 0.00,  val loss 0.573467, percent error 11.20
# Epoch    96, train loss 0.001066, train error 0.00,  val loss 0.574493, percent error 11.10
# Epoch    97, train loss 0.001060, train error 0.00,  val loss 0.575000, percent error 11.10
# Epoch    98, train loss 0.001055, train error 0.00,  val loss 0.574936, percent error 11.20
# Epoch    99, train loss 0.001050, train error 0.00,  val loss 0.575492, percent error 11.20
